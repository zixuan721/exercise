# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=    1  ,  
                out_channels=  32   ,
                kernel_size=  7    ,
                stride=    1       ,
                padding=   3       ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=5,
                stride=1,
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(2)
         

        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(  x.size(0), -1 )  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:28<00:00, 345471.40it/s]
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 240847.98it/s]
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:03<00:00, 535832.12it/s]
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 8326280.06it/s]
# c:\Users\huodi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\huodi\AppData\Local\Temp\ipykernel_208\977600053.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# c:\Users\huodi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
# C:\Users\huodi\AppData\Local\Temp\ipykernel_208\977600053.py:74: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.288 ==========
# ========== 40 ===== ===== test accuracy is  0.312 ==========
# ========== 60 ===== ===== test accuracy is  0.458 ==========
# ========== 80 ===== ===== test accuracy is  0.532 ==========
# ========== 100 ===== ===== test accuracy is  0.602 ==========
# ========== 120 ===== ===== test accuracy is  0.656 ==========
# ========== 140 ===== ===== test accuracy is  0.718 ==========
# ========== 160 ===== ===== test accuracy is  0.722 ==========
# ========== 180 ===== ===== test accuracy is  0.75 ==========
# ========== 200 ===== ===== test accuracy is  0.76 ==========
# ========== 220 ===== ===== test accuracy is  0.804 ==========
# ========== 240 ===== ===== test accuracy is  0.808 ==========
# ========== 260 ===== ===== test accuracy is  0.842 ==========
# ========== 280 ===== ===== test accuracy is  0.854 ==========
# ========== 300 ===== ===== test accuracy is  0.854 ==========
# ========== 320 ===== ===== test accuracy is  0.864 ==========
# ========== 340 ===== ===== test accuracy is  0.872 ==========
# ========== 360 ===== ===== test accuracy is  0.874 ==========
# ========== 380 ===== ===== test accuracy is  0.904 ==========
# ========== 400 ===== ===== test accuracy is  0.896 ==========
# ========== 420 ===== ===== test accuracy is  0.886 ==========
# ========== 440 ===== ===== test accuracy is  0.894 ==========
# ========== 460 ===== ===== test accuracy is  0.898 ==========
# ========== 480 ===== ===== test accuracy is  0.894 ==========
# ========== 500 ===== ===== test accuracy is  0.896 ==========
# ========== 520 ===== ===== test accuracy is  0.896 ==========
# ========== 540 ===== ===== test accuracy is  0.92 ==========
# ========== 560 ===== ===== test accuracy is  0.902 ==========
# ========== 580 ===== ===== test accuracy is  0.918 ==========
# ========== 600 ===== ===== test accuracy is  0.912 ==========
# ========== 620 ===== ===== test accuracy is  0.91 ==========
# ========== 640 ===== ===== test accuracy is  0.93 ==========
# ========== 660 ===== ===== test accuracy is  0.918 ==========
# ========== 680 ===== ===== test accuracy is  0.928 ==========
# ========== 700 ===== ===== test accuracy is  0.914 ==========
# ========== 720 ===== ===== test accuracy is  0.926 ==========
# ========== 740 ===== ===== test accuracy is  0.932 ==========
# ========== 760 ===== ===== test accuracy is  0.922 ==========
# ========== 780 ===== ===== test accuracy is  0.926 ==========
# ========== 800 ===== ===== test accuracy is  0.926 ==========
# ========== 820 ===== ===== test accuracy is  0.932 ==========
# ========== 840 ===== ===== test accuracy is  0.944 ==========
# ========== 860 ===== ===== test accuracy is  0.95 ==========
# ========== 880 ===== ===== test accuracy is  0.924 ==========
# ========== 900 ===== ===== test accuracy is  0.946 ==========
# ========== 920 ===== ===== test accuracy is  0.932 ==========
# ========== 940 ===== ===== test accuracy is  0.94 ==========
# ========== 960 ===== ===== test accuracy is  0.94 ==========
# ========== 980 ===== ===== test accuracy is  0.948 ==========
# ========== 1000 ===== ===== test accuracy is  0.946 ==========
# ========== 1020 ===== ===== test accuracy is  0.934 ==========
# ========== 1040 ===== ===== test accuracy is  0.94 ==========
# ========== 1060 ===== ===== test accuracy is  0.956 ==========
# ========== 1080 ===== ===== test accuracy is  0.942 ==========
# ========== 1100 ===== ===== test accuracy is  0.94 ==========
# ========== 1120 ===== ===== test accuracy is  0.952 ==========
# ========== 1140 ===== ===== test accuracy is  0.944 ==========
# ========== 1160 ===== ===== test accuracy is  0.95 ==========
# ========== 1180 ===== ===== test accuracy is  0.95 ==========
# ========== 20 ===== ===== test accuracy is  0.944 ==========
# ========== 40 ===== ===== test accuracy is  0.952 ==========
# ========== 60 ===== ===== test accuracy is  0.952 ==========
# ========== 80 ===== ===== test accuracy is  0.94 ==========
# ========== 100 ===== ===== test accuracy is  0.958 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.962 ==========
# ========== 160 ===== ===== test accuracy is  0.95 ==========
# ========== 180 ===== ===== test accuracy is  0.954 ==========
# ========== 200 ===== ===== test accuracy is  0.934 ==========
# ========== 220 ===== ===== test accuracy is  0.948 ==========
# ========== 240 ===== ===== test accuracy is  0.946 ==========
# ========== 260 ===== ===== test accuracy is  0.954 ==========
# ========== 280 ===== ===== test accuracy is  0.956 ==========
# ========== 300 ===== ===== test accuracy is  0.96 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.972 ==========
# ========== 360 ===== ===== test accuracy is  0.952 ==========
# ========== 380 ===== ===== test accuracy is  0.95 ==========
# ========== 400 ===== ===== test accuracy is  0.966 ==========
# ========== 420 ===== ===== test accuracy is  0.958 ==========
# ========== 440 ===== ===== test accuracy is  0.958 ==========
# ========== 460 ===== ===== test accuracy is  0.96 ==========
# ========== 480 ===== ===== test accuracy is  0.97 ==========
# ========== 500 ===== ===== test accuracy is  0.97 ==========
# ========== 520 ===== ===== test accuracy is  0.972 ==========
# ========== 540 ===== ===== test accuracy is  0.97 ==========
# ========== 560 ===== ===== test accuracy is  0.97 ==========
# ========== 580 ===== ===== test accuracy is  0.968 ==========
# ========== 600 ===== ===== test accuracy is  0.964 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.956 ==========
# ========== 660 ===== ===== test accuracy is  0.956 ==========
# ========== 680 ===== ===== test accuracy is  0.96 ==========
# ========== 700 ===== ===== test accuracy is  0.962 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.974 ==========
# ========== 760 ===== ===== test accuracy is  0.966 ==========
# ========== 780 ===== ===== test accuracy is  0.968 ==========
# ========== 800 ===== ===== test accuracy is  0.968 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.968 ==========
# ========== 860 ===== ===== test accuracy is  0.974 ==========
# ========== 880 ===== ===== test accuracy is  0.954 ==========
# ========== 900 ===== ===== test accuracy is  0.97 ==========
# ========== 920 ===== ===== test accuracy is  0.968 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.958 ==========
# ========== 980 ===== ===== test accuracy is  0.98 ==========
# ========== 1000 ===== ===== test accuracy is  0.968 ==========
# ========== 1020 ===== ===== test accuracy is  0.964 ==========
# ========== 1040 ===== ===== test accuracy is  0.97 ==========
# ========== 1060 ===== ===== test accuracy is  0.97 ==========
# ========== 1080 ===== ===== test accuracy is  0.976 ==========
# ========== 1100 ===== ===== test accuracy is  0.968 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.962 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.962 ==========
# ========== 20 ===== ===== test accuracy is  0.968 ==========
# ========== 40 ===== ===== test accuracy is  0.976 ==========
# ========== 60 ===== ===== test accuracy is  0.97 ==========
# ========== 80 ===== ===== test accuracy is  0.974 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.978 ==========
# ========== 140 ===== ===== test accuracy is  0.972 ==========
# ========== 160 ===== ===== test accuracy is  0.974 ==========
# ========== 180 ===== ===== test accuracy is  0.968 ==========
# ========== 200 ===== ===== test accuracy is  0.974 ==========
# ========== 220 ===== ===== test accuracy is  0.98 ==========
# ========== 240 ===== ===== test accuracy is  0.972 ==========
# ========== 260 ===== ===== test accuracy is  0.98 ==========
# ========== 280 ===== ===== test accuracy is  0.978 ==========
# ========== 300 ===== ===== test accuracy is  0.966 ==========
# ========== 320 ===== ===== test accuracy is  0.974 ==========
# ========== 340 ===== ===== test accuracy is  0.974 ==========
# ========== 360 ===== ===== test accuracy is  0.966 ==========
# ========== 380 ===== ===== test accuracy is  0.97 ==========
# ========== 400 ===== ===== test accuracy is  0.97 ==========
# ========== 420 ===== ===== test accuracy is  0.98 ==========
# ========== 440 ===== ===== test accuracy is  0.98 ==========
# ========== 460 ===== ===== test accuracy is  0.97 ==========
# ========== 480 ===== ===== test accuracy is  0.976 ==========
# ========== 500 ===== ===== test accuracy is  0.98 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.98 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.97 ==========
# ========== 600 ===== ===== test accuracy is  0.978 ==========
# ========== 620 ===== ===== test accuracy is  0.97 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.98 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.972 ==========
# ========== 720 ===== ===== test accuracy is  0.974 ==========
# ========== 740 ===== ===== test accuracy is  0.976 ==========
# ========== 760 ===== ===== test accuracy is  0.968 ==========
# ========== 780 ===== ===== test accuracy is  0.97 ==========
# ========== 800 ===== ===== test accuracy is  0.974 ==========
# ========== 820 ===== ===== test accuracy is  0.972 ==========
# ========== 840 ===== ===== test accuracy is  0.972 ==========
# ========== 860 ===== ===== test accuracy is  0.972 ==========
# ========== 880 ===== ===== test accuracy is  0.974 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.98 ==========
# ========== 940 ===== ===== test accuracy is  0.974 ==========
# ========== 960 ===== ===== test accuracy is  0.98 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.97 ==========
# ========== 1020 ===== ===== test accuracy is  0.972 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.976 ==========
# ========== 1080 ===== ===== test accuracy is  0.984 ==========
# ========== 1100 ===== ===== test accuracy is  0.972 ==========
# ========== 1120 ===== ===== test accuracy is  0.976 ==========
# ========== 1140 ===== ===== test accuracy is  0.974 ==========
# ========== 1160 ===== ===== test accuracy is  0.978 ==========
# ========== 1180 ===== ===== test accuracy is  0.978 ==========
